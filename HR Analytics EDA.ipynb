# %% [markdown]
# ## HR Analytics

# %% [markdown]
# ### 1. Import necessary libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ### 2. Import data from the csv file.
# We can also check out the dataframe using df.info(), df.head(), df.shape

# %%
df = pd.read_csv("hr.csv")
df.head()
# Out:
#    enrollee_id      city  city_development_index gender  \
# 0         8949  city_103                   0.920   Male
# 1        29725   city_40                   0.776   Male
# 2        11561   city_21                   0.624    NaN
# 3        33241  city_115                   0.789    NaN
# 4          666  city_162                   0.767   Male
#
#        relevent_experience enrolled_university education_level  \
# 0  Has relevent experience       no_enrollment        Graduate
# 1   No relevent experience       no_enrollment        Graduate
# 2   No relevent experience    Full time course        Graduate
# 3   No relevent experience                 NaN        Graduate
# 4  Has relevent experience       no_enrollment         Masters
#
#   major_discipline experience company_size    company_type last_new_job  \
# 0             STEM        >20          NaN             NaN            1
# 1             STEM         15        50-99         Pvt Ltd           >4
# 2             STEM          5          NaN             NaN        never
# 3  Business Degree         <1          NaN         Pvt Ltd        never
# 4             STEM        >20        50-99  Funded Startup            4
#
#    training_hours  target
# 0              36       1
# 1              47       0
# 2              83       0
# 3              52       1
# 4               8       0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19158 entries, 0 to 19157
# Data columns (total 14 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   enrollee_id             19158 non-null  int64
#  1   city                    19158 non-null  object
#  2   city_development_index  19158 non-null  float64
#  3   gender                  14650 non-null  object
#  4   relevent_experience     19158 non-null  object
#  5   enrolled_university     18772 non-null  object
#  6   education_level         18698 non-null  object
#  7   major_discipline        16345 non-null  object
#  8   experience              19093 non-null  object
#  9   company_size            13220 non-null  object
#  10  company_type            13018 non-null  object
#  11  last_new_job            18735 non-null  object
#  12  training_hours          19158 non-null  int64
#  13  target                  19158 non-null  int64
# dtypes: float64(1), int64(3), object(10)
# memory usage: 1.3+ MB

# %% [markdown]
# df.shape

# %% [markdown]
# ### 3. Let's check if there are any null values

# %%
df.isnull().sum()
# Out:
# enrollee_id                  0
# city                         0
# city_development_index       0
# gender                    4508
# relevent_experience          0
# enrolled_university        386
# education_level            460
# major_discipline          2813
# experience                  65
# company_size              5938
# company_type              6140
# last_new_job               423
# training_hours               0
# target                       0
# dtype: int64

# %% [markdown]
# It seems like there are a lot of null values. Let us drop them all for now. Also, we can call df.drop_duplicates() to remove any duplicates, if there is any

# %%
df = df.dropna().drop_duplicates()
df
# Out:
#        enrollee_id      city  city_development_index  gender  \
# 1            29725   city_40                   0.776    Male
# 4              666  city_162                   0.767    Male
# 7              402   city_46                   0.762    Male
# 8            27107  city_103                   0.920    Male
# 11           23853  city_103                   0.920    Male
# ...            ...       ...                     ...     ...
# 19147        21319   city_21                   0.624    Male
# 19149          251  city_103                   0.920    Male
# 19150        32313  city_160                   0.920  Female
# 19152        29754  city_103                   0.920  Female
# 19155        24576  city_103                   0.920    Male
#
#            relevent_experience enrolled_university education_level  \
# 1       No relevent experience       no_enrollment        Graduate
# 4      Has relevent experience       no_enrollment         Masters
# 7      Has relevent experience       no_enrollment        Graduate
# 8      Has relevent experience       no_enrollment        Graduate
# 11     Has relevent experience       no_enrollment        Graduate
# ...                        ...                 ...             ...
# 19147   No relevent experience    Full time course        Graduate
# 19149  Has relevent experience       no_enrollment         Masters
# 19150  Has relevent experience       no_enrollment        Graduate
# 19152  Has relevent experience       no_enrollment        Graduate
# 19155  Has relevent experience       no_enrollment        Graduate
#
#       major_discipline experience company_size    company_type last_new_job  \
# 1                 STEM         15        50-99         Pvt Ltd           >4
# 4                 STEM        >20        50-99  Funded Startup            4
# 7                 STEM         13          <10         Pvt Ltd           >4
# 8                 STEM          7        50-99         Pvt Ltd            1
# 11                STEM          5    5000-9999         Pvt Ltd            1
# ...                ...        ...          ...             ...          ...
# 19147             STEM          1      100-500         Pvt Ltd            1
# 19149             STEM          9        50-99         Pvt Ltd            1
# 19150             STEM         10      100-500   Public Sector            3
# 19152       Humanities          7       Oct-49  Funded Startup            1
# 19155             STEM        >20        50-99         Pvt Ltd            4
#
#        training_hours  target
# 1                  47       0
# 4                   8       0
# 7                  18       1
# 8                  46       1
# 11                108       0
# ...               ...     ...
# 19147              52       1
# 19149              36       1
# 19150              23       0
# 19152              25       0
# 19155              44       0
#
# [8955 rows x 14 columns]

# %% [markdown]
# ### 4. Let's reword the columns for readability

# %%
# Clean the column names
df.columns = ["id", "city", "city development index", "gender" , "relevant experience", "university", "education level", "major", "experience", "company size", "company type", "last new job", "training hours", "target"]

df.head()
# Out:
#        id      city  city development index gender      relevant experience  \
# 1   29725   city_40                   0.776   Male   No relevent experience
# 4     666  city_162                   0.767   Male  Has relevent experience
# 7     402   city_46                   0.762   Male  Has relevent experience
# 8   27107  city_103                   0.920   Male  Has relevent experience
# 11  23853  city_103                   0.920   Male  Has relevent experience
#
#        university education level major experience company size  \
# 1   no_enrollment        Graduate  STEM         15        50-99
# 4   no_enrollment         Masters  STEM        >20        50-99
# 7   no_enrollment        Graduate  STEM         13          <10
# 8   no_enrollment        Graduate  STEM          7        50-99
# 11  no_enrollment        Graduate  STEM          5    5000-9999
#
#       company type last new job  training hours  target
# 1          Pvt Ltd           >4              47       0
# 4   Funded Startup            4               8       0
# 7          Pvt Ltd           >4              18       1
# 8          Pvt Ltd            1              46       1
# 11         Pvt Ltd            1             108       0

# %% [markdown]
# ### 5. Let's also clean a few column data for better readability

# %%
# Clean the relevant experience column
df.loc[df["relevant experience"] == "No relevent experience", 'relevant experience'] = "No"
df.loc[df["relevant experience"] == "Has relevent experience", 'relevant experience'] = "Yes"

# Clean the university column
df.loc[df["university"] == "no_enrollment", 'university'] = "None"
df.loc[df["university"] == "Part time course", 'university'] = "Part time"
df.loc[df["university"] == "Full time course", 'university'] = "Full time"

target_df = df
target_df
# Out:
#           id      city  city development index  gender relevant experience  \
# 1      29725   city_40                   0.776    Male                  No
# 4        666  city_162                   0.767    Male                 Yes
# 7        402   city_46                   0.762    Male                 Yes
# 8      27107  city_103                   0.920    Male                 Yes
# 11     23853  city_103                   0.920    Male                 Yes
# ...      ...       ...                     ...     ...                 ...
# 19147  21319   city_21                   0.624    Male                  No
# 19149    251  city_103                   0.920    Male                 Yes
# 19150  32313  city_160                   0.920  Female                 Yes
# 19152  29754  city_103                   0.920  Female                 Yes
# 19155  24576  city_103                   0.920    Male                 Yes
#
#       university education level       major experience company size  \
# 1           None        Graduate        STEM         15        50-99
# 4           None         Masters        STEM        >20        50-99
# 7           None        Graduate        STEM         13          <10
# 8           None        Graduate        STEM          7        50-99
# 11          None        Graduate        STEM          5    5000-9999
# ...          ...             ...         ...        ...          ...
# 19147  Full time        Graduate        STEM          1      100-500
# 19149       None         Masters        STEM          9        50-99
# 19150       None        Graduate        STEM         10      100-500
# 19152       None        Graduate  Humanities          7       Oct-49
# 19155       None        Graduate        STEM        >20        50-99
#
#          company type last new job  training hours  target
# 1             Pvt Ltd           >4              47       0
# 4      Funded Startup            4               8       0
# 7             Pvt Ltd           >4              18       1
# 8             Pvt Ltd            1              46       1
# 11            Pvt Ltd            1             108       0
# ...               ...          ...             ...     ...
# 19147         Pvt Ltd            1              52       1
# 19149         Pvt Ltd            1              36       1
# 19150   Public Sector            3              23       0
# 19152  Funded Startup            1              25       0
# 19155         Pvt Ltd            4              44       0
#
# [8955 rows x 14 columns]

# %% [markdown]
# ### 6. In this HR Analytics problem, we only want to consider the education level, experience, and training hours. Thus, we will be removing any irrelevant columns.

# %%
target_df = target_df.drop(columns=["id", "city", "city development index", "company size", "company type", "last new job"])
target_df
# Out:
#        gender relevant experience university education level       major  \
# 1        Male                  No       None        Graduate        STEM
# 4        Male                 Yes       None         Masters        STEM
# 7        Male                 Yes       None        Graduate        STEM
# 8        Male                 Yes       None        Graduate        STEM
# 11       Male                 Yes       None        Graduate        STEM
# ...       ...                 ...        ...             ...         ...
# 19147    Male                  No  Full time        Graduate        STEM
# 19149    Male                 Yes       None         Masters        STEM
# 19150  Female                 Yes       None        Graduate        STEM
# 19152  Female                 Yes       None        Graduate  Humanities
# 19155    Male                 Yes       None        Graduate        STEM
#
#       experience  training hours  target
# 1             15              47       0
# 4            >20               8       0
# 7             13              18       1
# 8              7              46       1
# 11             5             108       0
# ...          ...             ...     ...
# 19147          1              52       1
# 19149          9              36       1
# 19150         10              23       0
# 19152          7              25       0
# 19155        >20              44       0
#
# [8955 rows x 8 columns]

# %% [markdown]
# ### 7. We wil reset the index for cleaner data

# %%
# Reset index
target_df = target_df.reset_index(drop=True)
target_df
# Out:
#       gender relevant experience university education level       major  \
# 0       Male                  No       None        Graduate        STEM
# 1       Male                 Yes       None         Masters        STEM
# 2       Male                 Yes       None        Graduate        STEM
# 3       Male                 Yes       None        Graduate        STEM
# 4       Male                 Yes       None        Graduate        STEM
# ...      ...                 ...        ...             ...         ...
# 8950    Male                  No  Full time        Graduate        STEM
# 8951    Male                 Yes       None         Masters        STEM
# 8952  Female                 Yes       None        Graduate        STEM
# 8953  Female                 Yes       None        Graduate  Humanities
# 8954    Male                 Yes       None        Graduate        STEM
#
#       experience  training hours  target
# 0             15              47       0
# 1             21               8       0
# 2             13              18       1
# 3              7              46       1
# 4              5             108       0
# ...          ...             ...     ...
# 8950           1              52       1
# 8951           9              36       1
# 8952          10              23       0
# 8953           7              25       0
# 8954          21              44       0
#
# [8955 rows x 8 columns]

# %% [markdown]
# ### 8. Now, let's count each element in every column

# %%
# Let's check how many males and females are interested in Data Science
target_df["gender"].value_counts()
# Out:
# Male      8073
# Female     804
# Other       78
# Name: gender, dtype: int64

# %% [markdown]
# #### It seems like there are significantly more male than female within data science industry.

# %%
# Let's check how many people have relevant experience or not
target_df["relevant experience"].value_counts()
# Out:
# Yes    7851
# No     1104
# Name: relevant experience, dtype: int64

# %% [markdown]
# #### Most people in this dataset have relevant data science experience.

# %%
# Let's check if an enrollment in a university helps
target_df["university"].value_counts()
# Out:
# None         7594
# Full time     832
# Part time     529
# Name: university, dtype: int64

# %% [markdown]
# #### Most of the candidates are not currently enrolled in a college course. That makes sense, as most of the candidates had relevant data science experience.

# %%
# What about education level?
target_df["education level"].value_counts()
# Out:
# Graduate    6252
# Masters     2449
# Phd          254
# Name: education level, dtype: int64

# %% [markdown]
# #### All of the candidates are on Graduate+ levels

# %%
# What about major?
target_df["major"].value_counts()

# They higly prefer STEM majors, but it's not impossible to get a job without a STEM major
# Out:
# STEM               7989
# Humanities          378
# Other               177
# Business Degree     170
# Arts                129
# No Major            112
# Name: major, dtype: int64

# %% [markdown]
# #### It is obvious that majority of the people are from STEM majors

# %% [markdown]
# #### The number of experience is categorial data in this case, so I changed >20 and <1 values to 21 and 0 respectively for better readability

# %%
# What about number of experience?
series = target_df["experience"]
series.loc[series == ">20"] = "21"
series.loc[series == "<1"] = "0"
series = series.astype(int)
series.sort_values().tail(20)
data = series.value_counts().sort_index()
data
# Out:
# c:\users\minjo\appdata\local\programs\python\python38-32\lib\site-packages\pandas\core\indexing.py:671: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_with_indexer(indexer, value)
# 0       97
# 1      121
# 2      297
# 3      428
# 4      480
# 5      575
# 6      535
# 7      485
# 8      398
# 9      533
# 10     551
# 11     372
# 12     293
# 13     235
# 14     333
# 15     398
# 16     304
# 17     206
# 18     168
# 19     179
# 20      86
# 21    1881
# Name: experience, dtype: int64

# %%
plt.bar(range(22), data)
plt.show()

# %% [markdown]
# #### People are mostly in their mid-career. However, we have to proceed with caution as "21" is actually 21+.

# %%
target_df["experience"] = series
target_df
# Out:
#       gender relevant experience university education level       major  \
# 0       Male                  No       None        Graduate        STEM
# 1       Male                 Yes       None         Masters        STEM
# 2       Male                 Yes       None        Graduate        STEM
# 3       Male                 Yes       None        Graduate        STEM
# 4       Male                 Yes       None        Graduate        STEM
# ...      ...                 ...        ...             ...         ...
# 8950    Male                  No  Full time        Graduate        STEM
# 8951    Male                 Yes       None         Masters        STEM
# 8952  Female                 Yes       None        Graduate        STEM
# 8953  Female                 Yes       None        Graduate  Humanities
# 8954    Male                 Yes       None        Graduate        STEM
#
#       experience  training hours  target
# 0             15              47       0
# 1             21               8       0
# 2             13              18       1
# 3              7              46       1
# 4              5             108       0
# ...          ...             ...     ...
# 8950           1              52       1
# 8951           9              36       1
# 8952          10              23       0
# 8953           7              25       0
# 8954          21              44       0
#
# [8955 rows x 8 columns]

# %% [markdown]
# ### 9. Let's group by each column to see the average data value

# %%
target_df.groupby("target").mean()
# Out:
#         experience  training hours
# target
# 0        12.214668       65.415016
# 1         8.718139       63.361430

# %% [markdown]
# #### Those with less experience tend to look for jobs more than those who don't.

# %%
target_df.groupby("university").mean()
# Out:
#             experience  training hours    target
# university
# Full time     7.105769       67.471154  0.278846
# None         12.323545       64.784962  0.153937
# Part time     8.884688       65.468809  0.155009

# %%
target_df.groupby("gender").mean()
# Out:
#         experience  training hours    target
# gender
# Female    9.856965       67.002488  0.162935
# Male     11.813700       64.959866  0.165985
# Other    11.538462       57.115385  0.153846

# %% [markdown]
# #### Females tend to have a bit less experience than males. It is possible that females took more training hours to compensate for lack of experience.

# %%
target_df.groupby("relevant experience")["training hours"].mean()
# Out:
# relevant experience
# No     62.250906
# Yes    65.472042
# Name: training hours, dtype: float64

# %% [markdown]
# #### Those who have relevant experience tend to have accumulated more training hours

# %%
target_df.groupby("education level").mean()
# Out:
#                  experience  training hours    target
# education level
# Graduate          10.985765       65.653391  0.174664
# Masters           12.792977       63.294406  0.145774
# Phd               16.472441       68.003937  0.133858

# %% [markdown]
# #### Those who have higher education tend to have more experience and training hours. They are also less likely to find jobs.
